# %% [markdown]
# # Optional Lab - Multi-class Classification

# %% [markdown]
# ## 1.1 Goals
# In this lab, you will explore an example of multi-class classification using neural networks.
# <figure>
#  <img src="./images/C2_W2_mclass_header.png"   style="width500px;height:200px;">
# </figure>

# %% [markdown]
# ## 1.2 Tools
# You will use some plotting routines. These are stored in `lab_utils_multiclass_TF.py` in this directory.

# %%
import sys
# !{sys.executable} -m pip install scikit-learn ipympl
# Out:
# Requirement already satisfied: scikit-learn in d:\anaconda\envs\ml-ng\lib\site-packages (1.7.2)
# Requirement already satisfied: ipympl in d:\anaconda\envs\ml-ng\lib\site-packages (0.9.8)
# Requirement already satisfied: numpy>=1.22.0 in d:\anaconda\envs\ml-ng\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in d:\anaconda\envs\ml-ng\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda\envs\ml-ng\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda\envs\ml-ng\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: ipython<10 in d:\anaconda\envs\ml-ng\lib\site-packages (from ipympl) (8.30.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in d:\anaconda\envs\ml-ng\lib\site-packages (from ipympl) (8.1.7)
# Requirement already satisfied: matplotlib<4,>=3.5.0 in d:\anaconda\envs\ml-ng\lib\site-packages (from ipympl) (3.10.8)
# Requirement already satisfied: pillow in d:\anaconda\envs\ml-ng\lib\site-packages (from ipympl) (11.1.0)
# Requirement already satisfied: traitlets<6 in d:\anaconda\envs\ml-ng\lib\site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: decorator in d:\anaconda\envs\ml-ng\lib\site-packages (from ipython<10->ipympl) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda\envs\ml-ng\lib\site-packages (from ipython<10->ipympl) (0.19.2)
# Requirement already satisfied: matplotlib-inline in d:\anaconda\envs\ml-ng\lib\site-packages (from ipython<10->ipympl) (0.2.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in d:\anaconda\envs\ml-ng\lib\site-packages (from ipython<10->ipympl) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in d:\anaconda\envs\ml-ng\lib\site-packages (from ipython<10->ipympl) (2.20.0)
# Requirement already satisfied: stack-data in d:\anaconda\envs\ml-ng\lib\site-packages (from ipython<10->ipympl) (0.6.3)
# Requirement already satisfied: exceptiongroup in d:\anaconda\envs\ml-ng\lib\site-packages (from ipython<10->ipympl) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.6 in d:\anaconda\envs\ml-ng\lib\site-packages (from ipython<10->ipympl) (4.15.0)
# Requirement already satisfied: colorama in d:\anaconda\envs\ml-ng\lib\site-packages (from ipython<10->ipympl) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in d:\anaconda\envs\ml-ng\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in d:\anaconda\envs\ml-ng\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in d:\anaconda\envs\ml-ng\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.16)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\envs\ml-ng\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\envs\ml-ng\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\envs\ml-ng\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda\envs\ml-ng\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\envs\ml-ng\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (26.0)
# Requirement already satisfied: pyparsing>=3 in d:\anaconda\envs\ml-ng\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\envs\ml-ng\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: wcwidth in d:\anaconda\envs\ml-ng\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<10->ipympl) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\anaconda\envs\ml-ng\lib\site-packages (from jedi>=0.16->ipython<10->ipympl) (0.8.5)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\ml-ng\lib\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.5.0->ipympl) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in d:\anaconda\envs\ml-ng\lib\site-packages (from stack-data->ipython<10->ipympl) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\anaconda\envs\ml-ng\lib\site-packages (from stack-data->ipython<10->ipympl) (3.0.1)
# Requirement already satisfied: pure_eval in d:\anaconda\envs\ml-ng\lib\site-packages (from stack-data->ipython<10->ipympl) (0.2.3)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from sklearn.datasets import make_blobs
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
np.set_printoptions(precision=2)
from lab_utils_multiclass_TF import *
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)
# Out:
# WARNING:tensorflow:From d:\Anaconda\envs\ml-ng\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # 2.0 Multi-class Classification
# Neural Networks are often used to classify data. Examples are neural networks:
# - take in photos and classify subjects in the photos as {dog,cat,horse,other}
# - take in a sentence and classify the 'parts of speech' of its elements: {noun, verb, adjective etc..}
#
# A network of this type will have multiple units in its final layer. Each output is associated with a category. When an input example is applied to the network, the output with the highest value is the category predicted. If the output is applied to a softmax function, the output of the softmax will provide probabilities of the input being in each category.
#
# In this lab you will see an example of building a multiclass network in Tensorflow. We will then take a look at how the neural network makes its predictions.
#
# Let's start by creating a four-class data set.

# %% [markdown]
# ## 2.1 Prepare and visualize our data
# We will use Scikit-Learn `make_blobs` function to make a training data set with 4 categories as shown in the plot below.

# %%
# make 4-class dataset for classification
classes = 4
m = 100
centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]]  #这里表示区分了四个样本数据点，使用sklearn的make_blobs函数生成数据集围绕点出现
std = 1.0
X_train, y_train = make_blobs(n_samples=m, centers=centers, cluster_std=std,random_state=30)

# %%
plt_mc(X_train,y_train,classes, centers, std=std)  #std表示数据集的分布范围是以一个圆为中心的
#y_train是一个一维数组，包含了每个样本所属的类别标签，范围从0到3。每个标签对应一个类别，表示该样本属于哪个类别。
#X_train是一个二维数组，包含了每个样本的特征值。
#y_train使得不同类型的显示不同的颜色
# Out:
# d:\CS\CS_CodeSpace\ml-study\lab_jupyter_notebook\Advanced_Learning_Algorithm\lab2\Files\home\jovyan\work\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# Each dot represents a training example. The axis (x0,x1) are the inputs and the color represents the class the example is associated with. Once trained, the model will be presented with a new example, (x0,x1), and will predict the class.
#
# While generated, this data set is representative of many real-world classification problems. There are several input features (x0,...,xn) and several output categories. The model is trained to use the input features to predict the correct output category.

# %%
# show classes in data set
print(f"unique classes {np.unique(y_train)}")
# show how classes are represented
print(f"class representation {y_train[:10]}")
# show shapes of our dataset
print(f"shape of X_train: {X_train.shape}, shape of y_train: {y_train.shape}")
# Out:
# unique classes [0 1 2 3]
# class representation [3 3 3 0 3 3 3 3 2 0]
# shape of X_train: (100, 2), shape of y_train: (100,)

# %% [markdown]
# ## 2.2 Model
# <img align="Right" src="./images/C2_W2_mclass_lab_network.PNG"  style=" width:350px; padding: 10px 20px ; ">
# This lab will use a 2-layer network as shown.
# Unlike the binary classification networks, this network has four outputs, one for each class. Given an input example, the output with the highest value is the predicted class of the input.
#
# Below is an example of how to construct this network in Tensorflow. Notice the output layer uses a `linear` rather than a `softmax` activation. While it is possible to include the softmax in the output layer, it is more numerically stable if linear outputs are passed to the loss function during training. If the model is used to predict probabilities, the softmax can be applied at that point.在读取预测的时候才使用softmax的函数作为使用

# %%
tf.random.set_seed(1234)  # applied to achieve consistent results
model = Sequential(
    [
        Dense(2, activation = 'relu',   name = "L1"),
        Dense(4, activation = 'linear', name = "L2")
    ]
)

# %% [markdown]
# The statements below compile and train the network. Setting `from_logits=True` as an argument to the loss function specifies that the output activation was linear rather than a softmax.

# %%
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

model.fit(
    X_train,y_train,
    epochs=200
)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 3ms/step - loss: 3.2830
# Epoch 2/200
# 4/4 [==============================] - 0s 2ms/step - loss: 2.9528
# Epoch 3/200
# 4/4 [==============================] - 0s 2ms/step - loss: 2.7252
# Epoch 4/200
# 4/4 [==============================] - 0s 1ms/step - loss: 2.4418
# Epoch 5/200
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2528
# Epoch 6/200
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0922
# Epoch 7/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9498
# Epoch 8/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.8258
# Epoch 9/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7103
# Epoch 10/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6246
# Epoch 11/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.5395
# Epoch 12/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4649
# Epoch 13/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3954
# Epoch 14/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3464
# Epoch 15/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.2934
# Epoch 16/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2530
# Epoch 17/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.2160
# Epoch 18/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.1819
# Epoch 19/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.1509
# Epoch 20/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1239
# Epoch 21/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0981
# Epoch 22/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0781
# Epoch 23/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0581
# Epoch 24/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0432
# Epoch 25/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0287
# Epoch 26/200
# 4/4 [==============================] - 0s 999us/step - loss: 1.0146
# Epoch 27/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0007
# Epoch 28/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9885
# Epoch 29/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9769
# Epoch 30/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.9655
# Epoch 31/200
# 4/4 [==============================] - 0s 841us/step - loss: 0.9543
# Epoch 32/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9433
# Epoch 33/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.9327
# Epoch 34/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.9212
# Epoch 35/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.9098
# Epoch 36/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8976
# Epoch 37/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8859
# Epoch 38/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8740
# Epoch 39/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8626
# Epoch 40/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8511
# Epoch 41/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8392
# Epoch 42/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8273
# Epoch 43/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8153
# Epoch 44/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8019
# Epoch 45/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7878
# Epoch 46/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7746
# Epoch 47/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7592
# Epoch 48/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7444
# Epoch 49/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7293
# Epoch 50/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7136
# Epoch 51/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6976
# Epoch 52/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6802
# Epoch 53/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6617
# Epoch 54/200
# 4/4 [==============================] - 0s 840us/step - loss: 0.6418
# Epoch 55/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6214
# Epoch 56/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5987
# Epoch 57/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5758
# Epoch 58/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5511
# Epoch 59/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5283
# Epoch 60/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5058
# Epoch 61/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4824
# Epoch 62/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4608
# Epoch 63/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4395
# Epoch 64/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4204
# Epoch 65/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4016
# Epoch 66/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3849
# Epoch 67/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3676
# Epoch 68/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3501
# Epoch 69/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3308
# Epoch 70/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3118
# Epoch 71/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2946
# Epoch 72/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2791
# Epoch 73/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2653
# Epoch 74/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2530
# Epoch 75/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2413
# Epoch 76/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2311
# Epoch 77/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2218
# Epoch 78/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2130
# Epoch 79/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2052
# Epoch 80/200
# 4/4 [==============================] - 0s 1000us/step - loss: 0.1976
# Epoch 81/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1907
# Epoch 82/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1841
# Epoch 83/200
# 4/4 [==============================] - 0s 999us/step - loss: 0.1779
# Epoch 84/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1722
# Epoch 85/200
# 4/4 [==============================] - 0s 1000us/step - loss: 0.1665
# Epoch 86/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1616
# Epoch 87/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1565
# Epoch 88/200
# 4/4 [==============================] - 0s 1000us/step - loss: 0.1517
# Epoch 89/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1472
# Epoch 90/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1428
# Epoch 91/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1386
# Epoch 92/200
# 4/4 [==============================] - 0s 668us/step - loss: 0.1346
# Epoch 93/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1310
# Epoch 94/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1269
# Epoch 95/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1231
# Epoch 96/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1197
# Epoch 97/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1161
# Epoch 98/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1132
# Epoch 99/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1100
# Epoch 100/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1073
# Epoch 101/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1046
# Epoch 102/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1021
# Epoch 103/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0996
# Epoch 104/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0970
# Epoch 105/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0947
# Epoch 106/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0924
# Epoch 107/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0903
# Epoch 108/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0880
# Epoch 109/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0860
# Epoch 110/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0840
# Epoch 111/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0823
# Epoch 112/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0805
# Epoch 113/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0788
# Epoch 114/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0772
# Epoch 115/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0755
# Epoch 116/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0739
# Epoch 117/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0725
# Epoch 118/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0712
# Epoch 119/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0697
# Epoch 120/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0685
# Epoch 121/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0671
# Epoch 122/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0659
# Epoch 123/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0646
# Epoch 124/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0634
# Epoch 125/200
# 4/4 [==============================] - 0s 1000us/step - loss: 0.0623
# Epoch 126/200
# 4/4 [==============================] - 0s 836us/step - loss: 0.0611
# Epoch 127/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0600
# Epoch 128/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0590
# Epoch 129/200
# 4/4 [==============================] - 0s 884us/step - loss: 0.0581
# Epoch 130/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0571
# Epoch 131/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0562
# Epoch 132/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0553
# Epoch 133/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0545
# Epoch 134/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0536
# Epoch 135/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0527
# Epoch 136/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0518
# Epoch 137/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0510
# Epoch 138/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0502
# Epoch 139/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0494
# Epoch 140/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0486
# Epoch 141/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0480
# Epoch 142/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0473
# Epoch 143/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0467
# Epoch 144/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0461
# Epoch 145/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0455
# Epoch 146/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0448
# Epoch 147/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0442
# Epoch 148/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0437
# Epoch 149/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0431
# Epoch 150/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0425
# Epoch 151/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0420
# Epoch 152/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0414
# Epoch 153/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0409
# Epoch 154/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0404
# Epoch 155/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0398
# Epoch 156/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0394
# Epoch 157/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0389
# Epoch 158/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0383
# Epoch 159/200
# 4/4 [==============================] - 0s 683us/step - loss: 0.0378
# Epoch 160/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0374
# Epoch 161/200
# 4/4 [==============================] - 0s 851us/step - loss: 0.0369
# Epoch 162/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0365
# Epoch 163/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0360
# Epoch 164/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0356
# Epoch 165/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0352
# Epoch 166/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0348
# Epoch 167/200
# 4/4 [==============================] - 0s 668us/step - loss: 0.0344
# Epoch 168/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 169/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0336
# Epoch 170/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 171/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0328
# Epoch 172/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0324
# Epoch 173/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0321
# Epoch 174/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0317
# Epoch 175/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0313
# Epoch 176/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0309
# Epoch 177/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0306
# Epoch 178/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0303
# Epoch 179/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0300
# Epoch 180/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0297
# Epoch 181/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0294
# Epoch 182/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0291
# Epoch 183/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0288
# Epoch 184/200
# 4/4 [==============================] - 0s 859us/step - loss: 0.0286
# Epoch 185/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0282
# Epoch 186/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0280
# Epoch 187/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0277
# Epoch 188/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0274
# Epoch 189/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0271
# Epoch 190/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0269
# Epoch 191/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 192/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 193/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0261
# Epoch 194/200
# 4/4 [==============================] - 0s 507us/step - loss: 0.0258
# Epoch 195/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0256
# Epoch 196/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 197/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0251
# Epoch 198/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0248
# Epoch 199/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0246
# Epoch 200/200
# 4/4 [==============================] - 0s 723us/step - loss: 0.0243

# %% [markdown]
# With the model trained, we can see how the model has classified the training data.

# %%
plt_cat_mc(X_train, y_train, model, classes)
# Out:
# 172/184 [===========================>..] - ETA: 0s
# d:\CS\CS_CodeSpace\ml-study\lab_jupyter_notebook\Advanced_Learning_Algorithm\lab2\Files\home\jovyan\work\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# 184/184 [==============================] - 0s 588us/step
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# Above, the decision boundaries show how the model has partitioned the input space.  This very simple model has had no trouble classifying the training data. How did it accomplish this? Let's look at the network in more detail.
#
# Below, we will pull the trained weights from the model and use that to plot the function of each of the network units. Further down, there is a more detailed explanation of the results. You don't need to know these details to successfully use neural networks, but it may be helpful to gain more intuition about how the layers combine to solve a classification problem.

# %%
# gather the trained parameters from the first layer
l1 = model.get_layer("L1") #relu层max(w * x,0)
W1,b1 = l1.get_weights()

# %%
# plot the function of the first layer
plt_layer_relu(X_train, y_train.reshape(-1,), W1, b1, classes) #有两个神经元
# Out:
# d:\CS\CS_CodeSpace\ml-study\lab_jupyter_notebook\Advanced_Learning_Algorithm\lab2\Files\home\jovyan\work\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# d:\CS\CS_CodeSpace\ml-study\lab_jupyter_notebook\Advanced_Learning_Algorithm\lab2\Files\home\jovyan\work\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# gather the trained parameters from the output layer
l2 = model.get_layer("L2")
W2, b2 = l2.get_weights()
# create the 'new features', the training examples after L1 transformation
Xl2 = np.maximum(0, np.dot(X_train,W1) + b1)

plt_output_layer_linear(Xl2, y_train.reshape(-1,), W2, b2, classes,
                        x0_rng = (-0.25,np.amax(Xl2[:,0])), x1_rng = (-0.25,np.amax(Xl2[:,1])))
# Out:
# d:\CS\CS_CodeSpace\ml-study\lab_jupyter_notebook\Advanced_Learning_Algorithm\lab2\Files\home\jovyan\work\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# d:\CS\CS_CodeSpace\ml-study\lab_jupyter_notebook\Advanced_Learning_Algorithm\lab2\Files\home\jovyan\work\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# d:\CS\CS_CodeSpace\ml-study\lab_jupyter_notebook\Advanced_Learning_Algorithm\lab2\Files\home\jovyan\work\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# d:\CS\CS_CodeSpace\ml-study\lab_jupyter_notebook\Advanced_Learning_Algorithm\lab2\Files\home\jovyan\work\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# ## Explanation
# #### Layer 1 <img align="Right" src="./images/C2_W2_mclass_layer1.png"  style=" width:600px; padding: 10px 20px ; ">
# These plots show the function of Units 0 and 1 in the first layer of the network. The inputs are ($x_0,x_1$) on the axis. The output of the unit is represented by the color of the background. This is indicated by the color bar on the right of each graph. Notice that since these units are using a ReLu, the outputs do not necessarily fall between 0 and 1 and in this case are greater than 20 at their peaks.
# The contour lines in this graph show the transition point between the output, $a^{[1]}_j$ being zero and non-zero. Recall the graph for a ReLu :<img align="right" src="./images/C2_W2_mclass_relu.png"  style=" width:200px; padding: 10px 20px ; "> The contour line in the graph is the inflection point in the ReLu.
#
# Unit 0 has separated classes 0 and 1 from classes 2 and 3. Points to the left of the line (classes 0 and 1) will output zero, while points to the right will output a value greater than zero.
# Unit 1 has separated classes 0 and 2 from classes 1 and 3. Points above the line (classes 0 and 2 ) will output a zero, while points below will output a value greater than zero. Let's see how this works out in the next layer!

# %% [markdown]
# #### Layer 2, the output layer  <img align="Right" src="./images/C2_W2_mclass_layer2.png"  style=" width:600px; padding: 10px 20px ; ">
#
# The dots in these graphs are the training examples translated by the first layer. One way to think of this is the first layer has created a new set of features for evaluation by the 2nd layer. The axes in these plots are the outputs of the previous layer $a^{[1]}_0$ and $a^{[1]}_1$. As predicted above, classes 0 and 1 (blue and green) have  $a^{[1]}_0 = 0$ while classes 0 and 2 (blue and orange) have $a^{[1]}_1 = 0$.
# Once again, the intensity of the background color indicates the highest values.  这里使用背景色的深浅度表示更高的输出值。也就是对应了每一个神经元（最后一层）表示为对应一个种类
# Unit 0 will produce its maximum value for values near (0,0), where class 0 (blue) has been mapped.
# Unit 1 produces its highest values in the upper left corner selecting class 1 (green).
# Unit 2 targets the lower right corner where class 2 (orange) resides.
# Unit 3 produces its highest values in the upper right selecting our final class (purple).
#
# One other aspect that is not obvious from the graphs is that the values have been coordinated between the units. It is not sufficient for a unit to produce a maximum value for the class it is selecting for, it must also be the highest value of all the units for points in that class. This is done by the implied softmax function that is part of the loss function (`SparseCategoricalCrossEntropy`). Unlike other activation functions, the softmax works across all the outputs.（也就是表示每一个神经元的输出，其相对的值也是最高的）
#
# You can successfully use neural networks without knowing the details of what each unit is up to. Hopefully, this example has provided some intuition about what is happening under the hood.

# %% [markdown]
# ## Congratulations!
# You have learned to build and operate a neural network for multiclass classification.
